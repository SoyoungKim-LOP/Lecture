# %%
# %matplotlib inline
from matplotlib import pyplot as plt

plt.rc("axes", unicode_minus=False)
plt.rc("font", family="Malgun Gothic")

import pandas as pd

# %%
scatter_df = pd.read_excel("Data/sample-line.xlsx", index_col='종목명')
print(scatter_df.shape)
scatter_df.head()
# Out:
# (50, 12)
#           N     현재가    전일비     등락률   액면가     시가총액    상장주식수  외국인비율       거래량  \
# 종목명
# 삼성전자      1   59700    200 -0.0033   100  3563960  5969783  55.95  24400594
# SK하이닉스    2   82900    500 -0.0060  5000   603514   728002  48.86   2872177
# NAVER     3  301000   4000 -0.0131   100   494433   164263  55.49    755573
# LG화학      4  692000  12000  0.0176  5000   488499    70592  37.61    541159
# 삼성바이오로직스  5  715000   6000 -0.0083  2500   473080    66165  10.16     75060
#
#              PER    ROE  토론실
# 종목명
# 삼성전자       18.68   8.69  NaN
# SK하이닉스     26.40   4.25  NaN
# NAVER      70.16  10.56  NaN
# LG화학      119.29   1.84  NaN
# 삼성바이오로직스  137.74   4.77  NaN

# %%
scatter_df.plot()

# %%
scatter_df.plot(kind='scatter', x =scatter_df['현재가'], y = scatter_df['외국인비율'])  # 이러면 에러납니다.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-0b4bcedd1832> in <module>
# ----> 1 scatter_df.plot(kind='scatter', x =scatter_df['현재가'], y = scatter_df['외국인비율'])
#
# C:\Anaconda3\envs\cuda-tensorflow\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     790         if kind in self._dataframe_kinds:
#     791             if isinstance(data, ABCDataFrame):
# --> 792                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     793             else:
#     794                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# C:\Anaconda3\envs\cuda-tensorflow\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
scatter1_df = 
scatter_df.plot(kind='scatter', x =scatter_df['현재가'], y = scatter_df['외국인비율'])

# %%
# scatter_df.index
val_01 = scatter_df['현재가']    # index_col='종목명'을 넣으니 에러가 발생. 이유는 뭘까? 
val_02 = scatter_df['외국인비율']
scatter_df1 = pd.DataFrame({'현재가':val_01, 
                        '외국인비율':val_02}, index=scatter_df.index)
print(scatter_df1.shape)
scatter_df1.head()
# Out:
# (50, 2)
#              현재가  외국인비율
# 종목명
# 삼성전자       59700  55.95
# SK하이닉스     82900  48.86
# NAVER     301000  55.49
# LG화학      692000  37.61
# 삼성바이오로직스  715000  10.16

# %%
scatter_df1.plot(kind='scatter', x='종목명', y='외국인비율')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\envs\cuda-tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '종목명'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-786af0eaf2e2> in <module>
# ...

# %%
scatter_df1.plot(kind='scatter', x='현재가', y='외국인비율', figsize=(10,10))

# %%
import seaborn as sns     # 추세선을 그리고 싶다면 seaborn을 임포트하라
import numpy as np

# %%
plt.figure(figsize=(10,10))
sns.regplot(data=scatter_df1, x='현재가', y='외국인비율')

# %%
plt.figure(figsize=(10,10))
x_min = np.min(scatter_df1['현재가'])
x_max = np.max(scatter_df1['현재가'])
y_min = np.min(scatter_df1['외국인비율'])
y_max = np.max(scatter_df1['외국인비율'])

# ax = sns.regplot(data=scatter_df1, x='현재가', y='외국인비율', fit_reg=True)
ax = sns.regplot(data=scatter_df1, x='현재가', y='외국인비율', fit_reg=False)     # fit_reg 옵션의 의미?
