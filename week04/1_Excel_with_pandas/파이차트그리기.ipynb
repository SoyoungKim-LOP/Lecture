# %%
# %matplotlib inline
from matplotlib import pyplot as plt

plt.rc("axes", unicode_minus=False)
plt.rc("font", family="Malgun Gothic")

import pandas as pd

# %%
pie_df = pd.read_excel("Data/sample-line.xlsx", index_col='종목명')
print(pie_df.shape)
pie_df.head()
# Out:
# (50, 12)
#           N     현재가    전일비     등락률   액면가     시가총액    상장주식수  외국인비율       거래량  \
# 종목명
# 삼성전자      1   59700    200 -0.0033   100  3563960  5969783  55.95  24400594
# SK하이닉스    2   82900    500 -0.0060  5000   603514   728002  48.86   2872177
# NAVER     3  301000   4000 -0.0131   100   494433   164263  55.49    755573
# LG화학      4  692000  12000  0.0176  5000   488499    70592  37.61    541159
# 삼성바이오로직스  5  715000   6000 -0.0083  2500   473080    66165  10.16     75060
#
#              PER    ROE  토론실
# 종목명
# 삼성전자       18.68   8.69  NaN
# SK하이닉스     26.40   4.25  NaN
# NAVER      70.16  10.56  NaN
# LG화학      119.29   1.84  NaN
# 삼성바이오로직스  137.74   4.77  NaN

# %%
pie_df.plot()

# %%
pie_df['거래량'].plot()

# %%
#pie_df.plot(kind='pie', y='거래량')
pie_df.plot(kind='pie', y='거래량', legend=False, figsize=(5,5))

# %%
pie_df.iloc[:5].plot(kind='pie', y='거래량', legend=False, figsize=(5,5)) # 상위 5개의 종목만 표시하기 iloc[:5]

# %%
pie_df.iloc[:1]   #
# Out:
#       N    현재가  전일비     등락률  액면가     시가총액    상장주식수  외국인비율       거래량    PER  \
# 종목명
# 삼성전자  1  59700  200 -0.0033  100  3563960  5969783  55.95  24400594  18.68
#
#        ROE  토론실
# 종목명
# 삼성전자  8.69  NaN

# %%
pie_df.loc[:1]  # 에러가 발생함. 이유가 궁금함. [사용한 데이터에 인덱스 번호가 없어서 일까요?]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-89320736132d> in <module>
# ----> 1 pie_df.loc[:1]  # 에러가 발생함. 이유가 궁금함. [사용한 데이터에 인덱스 번호가 없어서 일까요?]
#
# C:\Anaconda3\envs\cuda-tensorflow\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# C:\Anaconda3\envs\cuda-tensorflow\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909         if isinstance(key, slice):
#    1910             self._validate_key(key, axis)
# -> 1911             return self._get_slice_axis(key, axis=axis)
#    1912         elif com.is_bool_indexer(key):
#    1913             return self._getbool_axis(key, axis=axis)
#
# ...
